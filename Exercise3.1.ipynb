# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
drinks.sample(50)
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 189               Vietnam            111                2              1
# 16                Belgium            295               84            212
# 40           Cook Islands              0              254             74
# 73                  Haiti              1              326              1
# 116               Myanmar              5                1              0
# 105                 Malta            149              100            120
# 137                 Qatar              1               42              7
# 142                Rwanda             43                2              0
# 181  United Arab Emirates             16              135              5
# 22               Botswana            173               35             35
# 192              Zimbabwe             64               18              4
# 95                Lesotho             82               29              0
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby(by=["continent"]).beer_servings.mean().sort_values(ascending=False).round(2)
# Out:
# continent
# EU    193.78
# SA    175.08
# OC     89.69
# AF     61.47
# AS     37.05
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby(by=["continent"]).wine_servings.describe().round(2)
# Out:
#            count    mean    std  min   25%    50%     75%    max
# continent
# AF          53.0   16.26  38.85  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.07  21.67  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.22  97.42  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.62  64.56  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.42  88.62  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby(by=["continent"]).mean().round(2)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                 61.47            16.34          16.26
# AS                 37.05            60.84           9.07
# EU                193.78           132.56         142.22
# OC                 89.69            58.44          35.62
# SA                175.08           114.75          62.42
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 3.01
# AS                                 2.17
# EU                                 8.62
# OC                                 3.38
# SA                                 6.31

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby(by="continent").median().sort_values(by="total_litres_of_pure_alcohol",ascending=False)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU                 219.0            122.0          128.0
# SA                 162.5            108.5           12.0
# AF                  32.0              3.0            2.0
# OC                  52.5             37.0            8.5
# AS                  17.5             16.0            1.0
#
#            total_litres_of_pure_alcohol
# continent
# EU                                10.00
# SA                                 6.85
# AF                                 2.30
# OC                                 1.75
# AS                                 1.20

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby(by=["continent"]).spirit_servings.agg(["mean","min","max"]).round(2).sort_values(by="mean",ascending=False)
# Out:
#              mean  min  max
# continent
# EU         132.56    0  373
# SA         114.75   25  302
# AS          60.84    0  326
# OC          58.44    0  254
# AF          16.34    0  152
